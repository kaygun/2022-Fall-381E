# %%
from xmltodict import parse
from urllib.request import urlopen

import  matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

import pandas as pd
import json
import yaml

import numpy as np

# %% [markdown]
# # Different Data Formats
#
# ## Comma Separated Vectors (CSV)
#
# [Comma Separated Vector](https://en.wikipedia.org/wiki/Comma-separated_values) format is probably simplest data format out there. Here is a sample:

# %%
# data = pd.read_csv('https://data.transportation.gov/api/views/keg4-3bc2/rows.csv?accessType=DOWNLOAD')
data = pd.read_csv('./data/Border_Crossing_Entry_Data.csv')
data
# Out:
#         Port Name       State  Port Code            Border      Date  \
# 0          Calais       Maine        115  US-Canada Border  Aug 2022
# 1         Warroad   Minnesota       3423  US-Canada Border  May 2016
# 2          Laredo       Texas       2304  US-Mexico Border  Mar 2020
# 3          Scobey     Montana       3309  US-Canada Border  Jul 2020
# 4       Madawaska       Maine        109  US-Canada Border  Oct 2019
# ...           ...         ...        ...               ...       ...
# 376714  Otay Mesa  California       2506  US-Mexico Border  Jul 1996
# 376715    Warroad   Minnesota       3423  US-Canada Border  Apr 1996
# 376716  Nighthawk  Washington       3011  US-Canada Border  Nov 1996
# 376717  Madawaska       Maine        109  US-Canada Border  Sep 1996
# 376718   Danville  Washington       3012  US-Canada Border  Apr 1996
#
#                             Measure   Value  Latitude  Longitude  \
# 0                            Trucks    6175    45.189    -67.275
# 1                             Buses      52    48.999    -95.377
# 2                            Trucks  203861    27.500    -99.507
# 3                            Trucks      81    49.000   -105.408
# 4                            Trucks     187    47.360    -68.329
# ...                             ...     ...       ...        ...
# 376714        Rail Containers Empty     513    32.550   -116.939
# 376715      Truck Containers Loaded    1115    48.999    -95.377
# 376716                        Buses       0    49.000   -119.671
# 376717  Personal Vehicle Passengers  154139    47.360    -68.329
# 376718                  Pedestrians     179    49.000   -118.504
#
#                                 Point
# 0        POINT (-67.275381 45.188548)
# 1           POINT (-95.376555 48.999)
# 2        POINT (-99.507412 27.499561)
# 3       POINT (-105.407638 48.999527)
# 4        POINT (-68.328684 47.360052)
# ...                               ...
# 376714   POINT (-116.938538 32.55033)
# 376715      POINT (-95.376555 48.999)
# 376716   POINT (-119.67103 49.000144)
# 376717   POINT (-68.328684 47.360052)
# 376718  POINT (-118.503722 49.000083)
#
# [376719 rows x 10 columns]

# %%
data.shape
# Out:
# (376719, 10)

# %% [markdown]
# One can see this data as a large matrix where each row and each column has a name.
#
# For most of our purposes, we are going to access different data formats via [pandas](https://pandas.pydata.org/) python library using their [DataFrames](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html).
#
# One can access the data via these names:

# %%
data[['Date','Port Name','Measure','Value']]
# Out:
#             Date  Port Name                      Measure   Value
# 0       Aug 2022     Calais                       Trucks    6175
# 1       May 2016    Warroad                        Buses      52
# 2       Mar 2020     Laredo                       Trucks  203861
# 3       Jul 2020     Scobey                       Trucks      81
# 4       Oct 2019  Madawaska                       Trucks     187
# ...          ...        ...                          ...     ...
# 376714  Jul 1996  Otay Mesa        Rail Containers Empty     513
# 376715  Apr 1996    Warroad      Truck Containers Loaded    1115
# 376716  Nov 1996  Nighthawk                        Buses       0
# 376717  Sep 1996  Madawaska  Personal Vehicle Passengers  154139
# 376718  Apr 1996   Danville                  Pedestrians     179
#
# [376719 rows x 4 columns]

# %%
data.iloc[:10,:4]
# Out:
#        Port Name         State  Port Code            Border
# 0         Calais         Maine        115  US-Canada Border
# 1        Warroad     Minnesota       3423  US-Canada Border
# 2         Laredo         Texas       2304  US-Mexico Border
# 3         Scobey       Montana       3309  US-Canada Border
# 4      Madawaska         Maine        109  US-Canada Border
# 5         Laredo         Texas       2304  US-Mexico Border
# 6        Del Rio         Texas       2302  US-Mexico Border
# 7       Sherwood  North Dakota       3414  US-Canada Border
# 8  Beecher Falls       Vermont        206  US-Canada Border
# 9           Roma         Texas       2310  US-Mexico Border

# %% [markdown]
# You may even filter. For example, let us find the stations where monthly passenger count was larger than half a million in the year 2019.

# %%
data[data["Value"]>10000]
# Out:
#              Port Name     State  Port Code            Border      Date  \
# 2               Laredo     Texas       2304  US-Mexico Border  Mar 2020
# 12              Laredo     Texas       2304  US-Mexico Border  Nov 2021
# 32              Laredo     Texas       2304  US-Mexico Border  Nov 2020
# 67              Laredo     Texas       2304  US-Mexico Border  May 2018
# 87              Laredo     Texas       2304  US-Mexico Border  Jun 2018
# ...                ...       ...        ...               ...       ...
# 376684            Naco   Arizona       2603  US-Mexico Border  Sep 1996
# 376700  Alexandria Bay  New York        708  US-Canada Border  Feb 1996
# 376701         Detroit  Michigan       3801  US-Canada Border  Sep 1996
# 376711     Brownsville     Texas       2301  US-Mexico Border  Nov 1996
# 376717       Madawaska     Maine        109  US-Canada Border  Sep 1996
#
#                             Measure    Value  Latitude  Longitude  \
# 2                            Trucks   203861    27.500    -99.507
# 12                           Trucks   221978    27.500    -99.507
# 32                           Trucks   212898    27.500    -99.507
# 67                           Trucks   200723    27.500    -99.507
# 87                           Trucks   193582    27.500    -99.507
# ...                             ...      ...       ...        ...
# 376684            Personal Vehicles    23190    31.334   -109.948
# 376700            Personal Vehicles    33477    44.347    -75.984
# 376701                       Trucks   113465    42.332    -83.048
# 376711  Personal Vehicle Passengers  1169385    25.952    -97.401
# 376717  Personal Vehicle Passengers   154139    47.360    -68.329
#
#                                 Point
# 2        POINT (-99.507412 27.499561)
# 12       POINT (-99.507412 27.499561)
# 32       POINT (-99.507412 27.499561)
# 67       POINT (-99.507412 27.499561)
# 87       POINT (-99.507412 27.499561)
# ...                               ...
# 376684  POINT (-109.948413 31.334084)
# 376700   POINT (-75.983592 44.347229)
# 376701   POINT (-83.047924 42.331685)
# 376711     POINT (-97.40067 25.95155)
# 376717   POINT (-68.328684 47.360052)
#
# [60328 rows x 10 columns]

# %% [markdown]
# Now, notice something: the values in the Date column are stored as a string and not as a date. So, we need to convert that.

# %%
data['Date'][0]
# Out:
# 'Aug 2022'

# %%
data['Date'] = pd.to_datetime(data['Date'])
data
# Out:
#         Port Name       State  Port Code            Border       Date  \
# 0          Calais       Maine        115  US-Canada Border 2022-08-01
# 1         Warroad   Minnesota       3423  US-Canada Border 2016-05-01
# 2          Laredo       Texas       2304  US-Mexico Border 2020-03-01
# 3          Scobey     Montana       3309  US-Canada Border 2020-07-01
# 4       Madawaska       Maine        109  US-Canada Border 2019-10-01
# ...           ...         ...        ...               ...        ...
# 376714  Otay Mesa  California       2506  US-Mexico Border 1996-07-01
# 376715    Warroad   Minnesota       3423  US-Canada Border 1996-04-01
# 376716  Nighthawk  Washington       3011  US-Canada Border 1996-11-01
# 376717  Madawaska       Maine        109  US-Canada Border 1996-09-01
# 376718   Danville  Washington       3012  US-Canada Border 1996-04-01
#
#                             Measure   Value  Latitude  Longitude  \
# 0                            Trucks    6175    45.189    -67.275
# 1                             Buses      52    48.999    -95.377
# 2                            Trucks  203861    27.500    -99.507
# 3                            Trucks      81    49.000   -105.408
# 4                            Trucks     187    47.360    -68.329
# ...                             ...     ...       ...        ...
# 376714        Rail Containers Empty     513    32.550   -116.939
# 376715      Truck Containers Loaded    1115    48.999    -95.377
# 376716                        Buses       0    49.000   -119.671
# 376717  Personal Vehicle Passengers  154139    47.360    -68.329
# 376718                  Pedestrians     179    49.000   -118.504
#
#                                 Point
# 0        POINT (-67.275381 45.188548)
# 1           POINT (-95.376555 48.999)
# 2        POINT (-99.507412 27.499561)
# 3       POINT (-105.407638 48.999527)
# 4        POINT (-68.328684 47.360052)
# ...                               ...
# 376714   POINT (-116.938538 32.55033)
# 376715      POINT (-95.376555 48.999)
# 376716   POINT (-119.67103 49.000144)
# 376717   POINT (-68.328684 47.360052)
# 376718  POINT (-118.503722 49.000083)
#
# [376719 rows x 10 columns]

# %% [markdown]
# We may even group, sum, take means etc.

# %%
res = data[(data['Date']>='2021-01-01') & 
           (data['Date']<='2021-12-31') & 
           (data['Measure']=='Trucks')][['Port Name','Value']].groupby('Port Name').sum()
res.sort_values('Value',ascending=False)
# Out:
#                          Value
# Port Name
# Laredo                 2568471
# Detroit                1398577
# Otay Mesa               936628
# Buffalo Niagara Falls   898320
# Port Huron              850354
# ...                        ...
# Whitlash                    86
# Port Angeles                33
# Ferry                       12
# Ambrose                      4
# Willow Creek                 1
#
# [99 rows x 1 columns]

# %%
np.unique(data['Measure'])
# Out:
# array(['Bus Passengers', 'Buses', 'Pedestrians',
#        'Personal Vehicle Passengers', 'Personal Vehicles',
#        'Rail Containers Empty', 'Rail Containers Loaded',
#        'Train Passengers', 'Trains', 'Truck Containers Empty',
#        'Truck Containers Loaded', 'Trucks'], dtype=object)

# %%
data[(data['Date']=='2022-01') & (data['Measure']=='Trucks')][['State','Port Name']].groupby('State').count()
# Out:
#               Port Name
# State
# Alaska                3
# Arizona               5
# California            3
# Idaho                 2
# Maine                10
# Michigan              3
# Minnesota             7
# Montana              10
# New Mexico            2
# New York              6
# North Dakota         17
# Texas                11
# Vermont               5
# Washington           10

# %% [markdown]
# ## Excel Files
#
# Microsoft excel files are structured data in a different format:

# %%
xls = pd.read_excel("https://data.ibb.gov.tr/dataset/321aa12d-a388-4c61-b915-522730b8230a/resource/f676e493-8995-4e50-90b3-5381da92627f/download/rayl-sistemler-hat-bazl-sefer-saylar.xlsx")
xls
# Out:
#         Tarih     M1     M2     M3     M4       M5    M6       M7      M9  \
# 0  2017-01-01  21575  22479  16561  11762      NaN  7502      NaN     NaN
# 1  2017-02-01  19488  20288  15012  10644      NaN  6776      NaN     NaN
# 2  2017-03-01  21582  22846  16689  11820      NaN  7650      NaN     NaN
# 3  2017-04-01  20870  21680  15967  11413      NaN  7260      NaN     NaN
# 4  2017-05-01  21568  22588  16575  11784      NaN  7518      NaN     NaN
# ..        ...    ...    ...    ...    ...      ...   ...      ...     ...
# 59 2021-12-01  21765  19130   8378  11692  11229.0  7590   9857.0  7275.0
# 60 2022-01-01  21648  18938   8138  11448  11074.0  7605  10149.0  7203.0
# 61 2022-02-01  19599  17164   7572  10508  10111.0  6854   9061.0  7544.0
# 62 2022-03-01  21677  19084   8378  11755  11099.0  7580  10077.0  7273.0
# 63 2022-04-01  21295  18774   8150  11558  10995.0  7560   9966.0  7020.0
#
#        T1     T4      T5     F1      T3     TF1     TF2
# 0   21497  12353     NaN  11950     NaN     NaN     NaN
# 1   19536  11188     NaN  10808     NaN     NaN     NaN
# 2   21714  12439     NaN  11978     NaN     NaN     NaN
# 3   20755  11949     NaN  11560     NaN     NaN     NaN
# 4   21612  12361     NaN  11604     NaN     NaN     NaN
# ..    ...    ...     ...    ...     ...     ...     ...
# 59  23579  12753  7978.0   8432  2335.0  2524.0  5165.0
# 60  22624  12333  7690.0   8438  2291.0  2171.0  4862.0
# 61  21223  11459  7036.0   9296  2070.0  2057.0  4677.0
# 62  23516  12734  7779.0  10136  2350.0  2944.0  5522.0
# 63  23684  12263  7691.0   9950  2225.0  3014.0  5928.0
#
# [64 rows x 16 columns]

# %%
xls['Tarih'] = pd.to_datetime(xls['Tarih'])
xls = xls.fillna(0)
xls.index = xls['Tarih']
xls
# Out:
#                 Tarih     M1     M2     M3     M4       M5    M6       M7  \
# Tarih
# 2017-01-01 2017-01-01  21575  22479  16561  11762      0.0  7502      0.0
# 2017-02-01 2017-02-01  19488  20288  15012  10644      0.0  6776      0.0
# 2017-03-01 2017-03-01  21582  22846  16689  11820      0.0  7650      0.0
# 2017-04-01 2017-04-01  20870  21680  15967  11413      0.0  7260      0.0
# 2017-05-01 2017-05-01  21568  22588  16575  11784      0.0  7518      0.0
# ...               ...    ...    ...    ...    ...      ...   ...      ...
# 2021-12-01 2021-12-01  21765  19130   8378  11692  11229.0  7590   9857.0
# 2022-01-01 2022-01-01  21648  18938   8138  11448  11074.0  7605  10149.0
# 2022-02-01 2022-02-01  19599  17164   7572  10508  10111.0  6854   9061.0
# 2022-03-01 2022-03-01  21677  19084   8378  11755  11099.0  7580  10077.0
# 2022-04-01 2022-04-01  21295  18774   8150  11558  10995.0  7560   9966.0
#
#                 M9     T1     T4      T5     F1      T3     TF1     TF2
# Tarih
# 2017-01-01     0.0  21497  12353     0.0  11950     0.0     0.0     0.0
# 2017-02-01     0.0  19536  11188     0.0  10808     0.0     0.0     0.0
# 2017-03-01     0.0  21714  12439     0.0  11978     0.0     0.0     0.0
# 2017-04-01     0.0  20755  11949     0.0  11560     0.0     0.0     0.0
# 2017-05-01     0.0  21612  12361     0.0  11604     0.0     0.0     0.0
# ...            ...    ...    ...     ...    ...     ...     ...     ...
# 2021-12-01  7275.0  23579  12753  7978.0   8432  2335.0  2524.0  5165.0
# 2022-01-01  7203.0  22624  12333  7690.0   8438  2291.0  2171.0  4862.0
# 2022-02-01  7544.0  21223  11459  7036.0   9296  2070.0  2057.0  4677.0
# 2022-03-01  7273.0  23516  12734  7779.0  10136  2350.0  2944.0  5522.0
# 2022-04-01  7020.0  23684  12263  7691.0   9950  2225.0  3014.0  5928.0
#
# [64 rows x 16 columns]

# %%
tot21 = xls[(xls['Tarih']>='2021-01-01') & (xls['Tarih']<='2021-12-31')].sum(axis=1)/1000
tot20 = xls[(xls['Tarih']>='2020-01-01') & (xls['Tarih']<='2020-12-31')].sum(axis=1)/1000
# Out:
# /tmp/ipykernel_196762/2670712826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tot21 = xls[(xls['Tarih']>='2021-01-01') & (xls['Tarih']<='2021-12-31')].sum(axis=1)/1000
# /tmp/ipykernel_196762/2670712826.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tot20 = xls[(xls['Tarih']>='2020-01-01') & (xls['Tarih']<='2020-12-31')].sum(axis=1)/1000

# %%
fig, ax = plt.subplots(2,figsize=(12,6))
ax[0].plot(tot20)
ax[1].plot(tot21)

# %%
(xls['M1']/1000).plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Tarih'>

# %% [markdown]
# # Javascript Object Notation (JSON)
#
# [JSON](https://en.wikipedia.org/wiki/JSON) data format is more verbose but is also flexible than CSV format. Here is a sample:

# %%
with open('./data/example.json') as file:
    raw = json.load(file)

raw
# Out:
# [{'firstName': 'John',
#   'lastName': 'Smith',
#   'isAlive': True,
#   'age': 27,
#   'address': {'streetAddress': '21 2nd Street',
#    'city': 'New York',
#    'state': 'NY',
#    'postalCode': '10021-3100'},
#   'phoneNumbers': [{'type': 'home', 'number': '212 555-1234'},
#    {'type': 'office', 'number': '646 555-4567'}],
#   'children': [],
#   'spouse': None},
#  {'firstName': 'Jane',
#   'lastName': 'Doe',
#   'isAlive': True,
#   'age': 29,
#   'address': {'streetAddress': '431 Main Street',
#    'city': 'San Fransisco',
#    'state': 'CA',
#    'postalCode': '50421'},
#   'phoneNumbers': [{'type': 'home', 'number': '561 555-1234'},
#    {'type': 'office', 'number': '555 555-4567'}],
#   'children': [],
#   'spouse': None}]

# %%
raw[0]['address']['city']
# Out:
# 'New York'

# %% [markdown]
# One thing you should notice is that we can import a JSON file directly as a python dictionary, or as an array of python dictionaries. The other thing you should notice is that python dictionaries, or array of dictionaries, are much more general since they allow any *hashable* python data structure to be a key.

# %%
xs = {(0,1): "a", -1: {0,1,2}, "b": [0,1,2], True: False}
xs
# Out:
# {(0, 1): 'a', -1: {0, 1, 2}, 'b': [0, 1, 2], True: False}

# %% [markdown]
# However, a JSON file when parsed can only have strings as keys:

# %%
with open("./data/example2.json") as file:
    tmp = json.load(file)
    
tmp
# Out:
# {'(0,1)': 'a', '-1': '{0,1,2}', 'b': [0, 1, 2], 'True': 'False'}

# %%
with open('./data/example.json') as file:
    df = pd.read_json(file)
    
df
# Out:
#   firstName lastName  isAlive  age  \
# 0      John    Smith     True   27
# 1      Jane      Doe     True   29
#
#                                              address  \
# 0  {'streetAddress': '21 2nd Street', 'city': 'Ne...
# 1  {'streetAddress': '431 Main Street', 'city': '...
#
#                                         phoneNumbers children  spouse
# 0  [{'type': 'home', 'number': '212 555-1234'}, {...       []     NaN
# 1  [{'type': 'home', 'number': '561 555-1234'}, {...       []     NaN

# %% [markdown]
# JSON data format is recursive. This means every named place could be another data that has the structure of a dictionary, or an array of dictionaries:

# %%
[ [y['number'] for y in x['phoneNumbers']] for x in raw ]
# Out:
# [['212 555-1234', '646 555-4567'], ['561 555-1234', '555 555-4567']]

# %%
raw[0]['phoneNumbers']
# Out:
# [{'type': 'home', 'number': '212 555-1234'},
#  {'type': 'office', 'number': '646 555-4567'}]

# %%
raw[1]['address']
# Out:
# {'streetAddress': '431 Main Street',
#  'city': 'San Fransisco',
#  'state': 'CA',
#  'postalCode': '50421'}

# %% [markdown]
# But most of the time, a JSON file is just another CSV file written in this format:

# %%
tmp = pd.read_csv('./data/iris.data', 
                  header=None)
tmp.columns=['petal.length',
             'petal.width',
             'sepal.length',
             'sepal.width',
             'variety']
tmp
# Out:
#      petal.length  petal.width  sepal.length  sepal.width         variety
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
with open('./data/iris.json') as file:
    js = json.load(file)
js
# Out:
# [{'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5.1',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '4.9',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  {'petal.length': '1.3',
#   'petal.width': '.2',
#   'sepal.length': '4.7',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '4.6',
#   'sepal.width': '3.1',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3.6',
#   'variety': 'Setosa'},
#  {'petal.length': '1.7',
#   'petal.width': '.4',
#   'sepal.length': '5.4',
#   'sepal.width': '3.9',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.3',
#   'sepal.length': '4.6',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '4.4',
#   'sepal.width': '2.9',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.1',
#   'sepal.length': '4.9',
#   'sepal.width': '3.1',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5.4',
#   'sepal.width': '3.7',
#   'variety': 'Setosa'},
#  {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '4.8',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.1',
#   'sepal.length': '4.8',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  {'petal.length': '1.1',
#   'petal.width': '.1',
#   'sepal.length': '4.3',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  {'petal.length': '1.2',
#   'petal.width': '.2',
#   'sepal.length': '5.8',
#   'sepal.width': '4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.4',
#   'sepal.length': '5.7',
#   'sepal.width': '4.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.3',
#   'petal.width': '.4',
#   'sepal.length': '5.4',
#   'sepal.width': '3.9',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.3',
#   'sepal.length': '5.1',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  {'petal.length': '1.7',
#   'petal.width': '.3',
#   'sepal.length': '5.7',
#   'sepal.width': '3.8',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.3',
#   'sepal.length': '5.1',
#   'sepal.width': '3.8',
#   'variety': 'Setosa'},
#  {'petal.length': '1.7',
#   'petal.width': '.2',
#   'sepal.length': '5.4',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.4',
#   'sepal.length': '5.1',
#   'sepal.width': '3.7',
#   'variety': 'Setosa'},
#  {'petal.length': '1',
#   'petal.width': '.2',
#   'sepal.length': '4.6',
#   'sepal.width': '3.6',
#   'variety': 'Setosa'},
#  {'petal.length': '1.7',
#   'petal.width': '.5',
#   'sepal.length': '5.1',
#   'sepal.width': '3.3',
#   'variety': 'Setosa'},
#  {'petal.length': '1.9',
#   'petal.width': '.2',
#   'sepal.length': '4.8',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  {'petal.length': '1.6',
#   'petal.width': '.4',
#   'sepal.length': '5',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5.2',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5.2',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '4.7',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '4.8',
#   'sepal.width': '3.1',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.4',
#   'sepal.length': '5.4',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.1',
#   'sepal.length': '5.2',
#   'sepal.width': '4.1',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5.5',
#   'sepal.width': '4.2',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '4.9',
#   'sepal.width': '3.1',
#   'variety': 'Setosa'},
#  {'petal.length': '1.2',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  {'petal.length': '1.3',
#   'petal.width': '.2',
#   'sepal.length': '5.5',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.1',
#   'sepal.length': '4.9',
#   'sepal.width': '3.6',
#   'variety': 'Setosa'},
#  {'petal.length': '1.3',
#   'petal.width': '.2',
#   'sepal.length': '4.4',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5.1',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  {'petal.length': '1.3',
#   'petal.width': '.3',
#   'sepal.length': '5',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  {'petal.length': '1.3',
#   'petal.width': '.3',
#   'sepal.length': '4.5',
#   'sepal.width': '2.3',
#   'variety': 'Setosa'},
#  {'petal.length': '1.3',
#   'petal.width': '.2',
#   'sepal.length': '4.4',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  {'petal.length': '1.6',
#   'petal.width': '.6',
#   'sepal.length': '5',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  {'petal.length': '1.9',
#   'petal.width': '.4',
#   'sepal.length': '5.1',
#   'sepal.width': '3.8',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.3',
#   'sepal.length': '4.8',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '5.1',
#   'sepal.width': '3.8',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '4.6',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5.3',
#   'sepal.width': '3.7',
#   'variety': 'Setosa'},
#  {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3.3',
#   'variety': 'Setosa'},
#  {'petal.length': '4.7',
#   'petal.width': '1.4',
#   'sepal.length': '7',
#   'sepal.width': '3.2',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '6.4',
#   'sepal.width': '3.2',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.9',
#   'petal.width': '1.5',
#   'sepal.length': '6.9',
#   'sepal.width': '3.1',
#   'variety': 'Versicolor'},
#  {'petal.length': '4',
#   'petal.width': '1.3',
#   'sepal.length': '5.5',
#   'sepal.width': '2.3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.6',
#   'petal.width': '1.5',
#   'sepal.length': '6.5',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.5',
#   'petal.width': '1.3',
#   'sepal.length': '5.7',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.7',
#   'petal.width': '1.6',
#   'sepal.length': '6.3',
#   'sepal.width': '3.3',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.3',
#   'petal.width': '1',
#   'sepal.length': '4.9',
#   'sepal.width': '2.4',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.6',
#   'petal.width': '1.3',
#   'sepal.length': '6.6',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.9',
#   'petal.width': '1.4',
#   'sepal.length': '5.2',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.5',
#   'petal.width': '1',
#   'sepal.length': '5',
#   'sepal.width': '2',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.2',
#   'petal.width': '1.5',
#   'sepal.length': '5.9',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4',
#   'petal.width': '1',
#   'sepal.length': '6',
#   'sepal.width': '2.2',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.7',
#   'petal.width': '1.4',
#   'sepal.length': '6.1',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.6',
#   'petal.width': '1.3',
#   'sepal.length': '5.6',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.4',
#   'petal.width': '1.4',
#   'sepal.length': '6.7',
#   'sepal.width': '3.1',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '5.6',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.1',
#   'petal.width': '1',
#   'sepal.length': '5.8',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '6.2',
#   'sepal.width': '2.2',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.9',
#   'petal.width': '1.1',
#   'sepal.length': '5.6',
#   'sepal.width': '2.5',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.8',
#   'petal.width': '1.8',
#   'sepal.length': '5.9',
#   'sepal.width': '3.2',
#   'variety': 'Versicolor'},
#  {'petal.length': '4',
#   'petal.width': '1.3',
#   'sepal.length': '6.1',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.9',
#   'petal.width': '1.5',
#   'sepal.length': '6.3',
#   'sepal.width': '2.5',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.7',
#   'petal.width': '1.2',
#   'sepal.length': '6.1',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.3',
#   'petal.width': '1.3',
#   'sepal.length': '6.4',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.4',
#   'petal.width': '1.4',
#   'sepal.length': '6.6',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.8',
#   'petal.width': '1.4',
#   'sepal.length': '6.8',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  {'petal.length': '5',
#   'petal.width': '1.7',
#   'sepal.length': '6.7',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '6',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.5',
#   'petal.width': '1',
#   'sepal.length': '5.7',
#   'sepal.width': '2.6',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.8',
#   'petal.width': '1.1',
#   'sepal.length': '5.5',
#   'sepal.width': '2.4',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.7',
#   'petal.width': '1',
#   'sepal.length': '5.5',
#   'sepal.width': '2.4',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.9',
#   'petal.width': '1.2',
#   'sepal.length': '5.8',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  {'petal.length': '5.1',
#   'petal.width': '1.6',
#   'sepal.length': '6',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '5.4',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.5',
#   'petal.width': '1.6',
#   'sepal.length': '6',
#   'sepal.width': '3.4',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.7',
#   'petal.width': '1.5',
#   'sepal.length': '6.7',
#   'sepal.width': '3.1',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.4',
#   'petal.width': '1.3',
#   'sepal.length': '6.3',
#   'sepal.width': '2.3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.1',
#   'petal.width': '1.3',
#   'sepal.length': '5.6',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4',
#   'petal.width': '1.3',
#   'sepal.length': '5.5',
#   'sepal.width': '2.5',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.4',
#   'petal.width': '1.2',
#   'sepal.length': '5.5',
#   'sepal.width': '2.6',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.6',
#   'petal.width': '1.4',
#   'sepal.length': '6.1',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4',
#   'petal.width': '1.2',
#   'sepal.length': '5.8',
#   'sepal.width': '2.6',
#   'variety': 'Versicolor'},
#  {'petal.length': '3.3',
#   'petal.width': '1',
#   'sepal.length': '5',
#   'sepal.width': '2.3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.2',
#   'petal.width': '1.3',
#   'sepal.length': '5.6',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.2',
#   'petal.width': '1.2',
#   'sepal.length': '5.7',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.2',
#   'petal.width': '1.3',
#   'sepal.length': '5.7',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.3',
#   'petal.width': '1.3',
#   'sepal.length': '6.2',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  {'petal.length': '3',
#   'petal.width': '1.1',
#   'sepal.length': '5.1',
#   'sepal.width': '2.5',
#   'variety': 'Versicolor'},
#  {'petal.length': '4.1',
#   'petal.width': '1.3',
#   'sepal.length': '5.7',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  {'petal.length': '6',
#   'petal.width': '2.5',
#   'sepal.length': '6.3',
#   'sepal.width': '3.3',
#   'variety': 'Virginica'},
#  {'petal.length': '5.1',
#   'petal.width': '1.9',
#   'sepal.length': '5.8',
#   'sepal.width': '2.7',
#   'variety': 'Virginica'},
#  {'petal.length': '5.9',
#   'petal.width': '2.1',
#   'sepal.length': '7.1',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '5.6',
#   'petal.width': '1.8',
#   'sepal.length': '6.3',
#   'sepal.width': '2.9',
#   'variety': 'Virginica'},
#  {'petal.length': '5.8',
#   'petal.width': '2.2',
#   'sepal.length': '6.5',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '6.6',
#   'petal.width': '2.1',
#   'sepal.length': '7.6',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '4.5',
#   'petal.width': '1.7',
#   'sepal.length': '4.9',
#   'sepal.width': '2.5',
#   'variety': 'Virginica'},
#  {'petal.length': '6.3',
#   'petal.width': '1.8',
#   'sepal.length': '7.3',
#   'sepal.width': '2.9',
#   'variety': 'Virginica'},
#  {'petal.length': '5.8',
#   'petal.width': '1.8',
#   'sepal.length': '6.7',
#   'sepal.width': '2.5',
#   'variety': 'Virginica'},
#  {'petal.length': '6.1',
#   'petal.width': '2.5',
#   'sepal.length': '7.2',
#   'sepal.width': '3.6',
#   'variety': 'Virginica'},
#  {'petal.length': '5.1',
#   'petal.width': '2',
#   'sepal.length': '6.5',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  {'petal.length': '5.3',
#   'petal.width': '1.9',
#   'sepal.length': '6.4',
#   'sepal.width': '2.7',
#   'variety': 'Virginica'},
#  {'petal.length': '5.5',
#   'petal.width': '2.1',
#   'sepal.length': '6.8',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '5',
#   'petal.width': '2',
#   'sepal.length': '5.7',
#   'sepal.width': '2.5',
#   'variety': 'Virginica'},
#  {'petal.length': '5.1',
#   'petal.width': '2.4',
#   'sepal.length': '5.8',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  {'petal.length': '5.3',
#   'petal.width': '2.3',
#   'sepal.length': '6.4',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  {'petal.length': '5.5',
#   'petal.width': '1.8',
#   'sepal.length': '6.5',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '6.7',
#   'petal.width': '2.2',
#   'sepal.length': '7.7',
#   'sepal.width': '3.8',
#   'variety': 'Virginica'},
#  {'petal.length': '6.9',
#   'petal.width': '2.3',
#   'sepal.length': '7.7',
#   'sepal.width': '2.6',
#   'variety': 'Virginica'},
#  {'petal.length': '5',
#   'petal.width': '1.5',
#   'sepal.length': '6',
#   'sepal.width': '2.2',
#   'variety': 'Virginica'},
#  {'petal.length': '5.7',
#   'petal.width': '2.3',
#   'sepal.length': '6.9',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  {'petal.length': '4.9',
#   'petal.width': '2',
#   'sepal.length': '5.6',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  {'petal.length': '6.7',
#   'petal.width': '2',
#   'sepal.length': '7.7',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  {'petal.length': '4.9',
#   'petal.width': '1.8',
#   'sepal.length': '6.3',
#   'sepal.width': '2.7',
#   'variety': 'Virginica'},
#  {'petal.length': '5.7',
#   'petal.width': '2.1',
#   'sepal.length': '6.7',
#   'sepal.width': '3.3',
#   'variety': 'Virginica'},
#  {'petal.length': '6',
#   'petal.width': '1.8',
#   'sepal.length': '7.2',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  {'petal.length': '4.8',
#   'petal.width': '1.8',
#   'sepal.length': '6.2',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  {'petal.length': '4.9',
#   'petal.width': '1.8',
#   'sepal.length': '6.1',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '5.6',
#   'petal.width': '2.1',
#   'sepal.length': '6.4',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  {'petal.length': '5.8',
#   'petal.width': '1.6',
#   'sepal.length': '7.2',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '6.1',
#   'petal.width': '1.9',
#   'sepal.length': '7.4',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  {'petal.length': '6.4',
#   'petal.width': '2',
#   'sepal.length': '7.9',
#   'sepal.width': '3.8',
#   'variety': 'Virginica'},
#  {'petal.length': '5.6',
#   'petal.width': '2.2',
#   'sepal.length': '6.4',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  {'petal.length': '5.1',
#   'petal.width': '1.5',
#   'sepal.length': '6.3',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  {'petal.length': '5.6',
#   'petal.width': '1.4',
#   'sepal.length': '6.1',
#   'sepal.width': '2.6',
#   'variety': 'Virginica'},
#  {'petal.length': '6.1',
#   'petal.width': '2.3',
#   'sepal.length': '7.7',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '5.6',
#   'petal.width': '2.4',
#   'sepal.length': '6.3',
#   'sepal.width': '3.4',
#   'variety': 'Virginica'},
#  {'petal.length': '5.5',
#   'petal.width': '1.8',
#   'sepal.length': '6.4',
#   'sepal.width': '3.1',
#   'variety': 'Virginica'},
#  {'petal.length': '4.8',
#   'petal.width': '1.8',
#   'sepal.length': '6',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '5.4',
#   'petal.width': '2.1',
#   'sepal.length': '6.9',
#   'sepal.width': '3.1',
#   'variety': 'Virginica'},
#  {'petal.length': '5.6',
#   'petal.width': '2.4',
#   'sepal.length': '6.7',
#   'sepal.width': '3.1',
#   'variety': 'Virginica'},
#  {'petal.length': '5.1',
#   'petal.width': '2.3',
#   'sepal.length': '6.9',
#   'sepal.width': '3.1',
#   'variety': 'Virginica'},
#  {'petal.length': '5.1',
#   'petal.width': '1.9',
#   'sepal.length': '5.8',
#   'sepal.width': '2.7',
#   'variety': 'Virginica'},
#  {'petal.length': '5.9',
#   'petal.width': '2.3',
#   'sepal.length': '6.8',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  {'petal.length': '5.7',
#   'petal.width': '2.5',
#   'sepal.length': '6.7',
#   'sepal.width': '3.3',
#   'variety': 'Virginica'},
#  {'petal.length': '5.2',
#   'petal.width': '2.3',
#   'sepal.length': '6.7',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '5',
#   'petal.width': '1.9',
#   'sepal.length': '6.3',
#   'sepal.width': '2.5',
#   'variety': 'Virginica'},
#  {'petal.length': '5.2',
#   'petal.width': '2',
#   'sepal.length': '6.5',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  {'petal.length': '5.4',
#   'petal.width': '2.3',
#   'sepal.length': '6.2',
#   'sepal.width': '3.4',
#   'variety': 'Virginica'},
#  {'petal.length': '5.1',
#   'petal.width': '1.8',
#   'sepal.length': '5.9',
#   'sepal.width': '3',
#   'variety': 'Virginica'}]

# %% [markdown]
# You may even convert formats:

# %%
df = pd.DataFrame(js)
df
# Out:
#     petal.length petal.width sepal.length sepal.width    variety
# 0            1.4          .2          5.1         3.5     Setosa
# 1            1.4          .2          4.9           3     Setosa
# 2            1.3          .2          4.7         3.2     Setosa
# 3            1.5          .2          4.6         3.1     Setosa
# 4            1.4          .2            5         3.6     Setosa
# ..           ...         ...          ...         ...        ...
# 145          5.2         2.3          6.7           3  Virginica
# 146            5         1.9          6.3         2.5  Virginica
# 147          5.2           2          6.5           3  Virginica
# 148          5.4         2.3          6.2         3.4  Virginica
# 149          5.1         1.8          5.9           3  Virginica
#
# [150 rows x 5 columns]

# %%
json.loads(df.transpose().to_json())
# Out:
# {'0': {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5.1',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  '1': {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '4.9',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  '2': {'petal.length': '1.3',
#   'petal.width': '.2',
#   'sepal.length': '4.7',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  '3': {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '4.6',
#   'sepal.width': '3.1',
#   'variety': 'Setosa'},
#  '4': {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3.6',
#   'variety': 'Setosa'},
#  '5': {'petal.length': '1.7',
#   'petal.width': '.4',
#   'sepal.length': '5.4',
#   'sepal.width': '3.9',
#   'variety': 'Setosa'},
#  '6': {'petal.length': '1.4',
#   'petal.width': '.3',
#   'sepal.length': '4.6',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '7': {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '8': {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '4.4',
#   'sepal.width': '2.9',
#   'variety': 'Setosa'},
#  '9': {'petal.length': '1.5',
#   'petal.width': '.1',
#   'sepal.length': '4.9',
#   'sepal.width': '3.1',
#   'variety': 'Setosa'},
#  '10': {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5.4',
#   'sepal.width': '3.7',
#   'variety': 'Setosa'},
#  '11': {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '4.8',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '12': {'petal.length': '1.4',
#   'petal.width': '.1',
#   'sepal.length': '4.8',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  '13': {'petal.length': '1.1',
#   'petal.width': '.1',
#   'sepal.length': '4.3',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  '14': {'petal.length': '1.2',
#   'petal.width': '.2',
#   'sepal.length': '5.8',
#   'sepal.width': '4',
#   'variety': 'Setosa'},
#  '15': {'petal.length': '1.5',
#   'petal.width': '.4',
#   'sepal.length': '5.7',
#   'sepal.width': '4.4',
#   'variety': 'Setosa'},
#  '16': {'petal.length': '1.3',
#   'petal.width': '.4',
#   'sepal.length': '5.4',
#   'sepal.width': '3.9',
#   'variety': 'Setosa'},
#  '17': {'petal.length': '1.4',
#   'petal.width': '.3',
#   'sepal.length': '5.1',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  '18': {'petal.length': '1.7',
#   'petal.width': '.3',
#   'sepal.length': '5.7',
#   'sepal.width': '3.8',
#   'variety': 'Setosa'},
#  '19': {'petal.length': '1.5',
#   'petal.width': '.3',
#   'sepal.length': '5.1',
#   'sepal.width': '3.8',
#   'variety': 'Setosa'},
#  '20': {'petal.length': '1.7',
#   'petal.width': '.2',
#   'sepal.length': '5.4',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '21': {'petal.length': '1.5',
#   'petal.width': '.4',
#   'sepal.length': '5.1',
#   'sepal.width': '3.7',
#   'variety': 'Setosa'},
#  '22': {'petal.length': '1',
#   'petal.width': '.2',
#   'sepal.length': '4.6',
#   'sepal.width': '3.6',
#   'variety': 'Setosa'},
#  '23': {'petal.length': '1.7',
#   'petal.width': '.5',
#   'sepal.length': '5.1',
#   'sepal.width': '3.3',
#   'variety': 'Setosa'},
#  '24': {'petal.length': '1.9',
#   'petal.width': '.2',
#   'sepal.length': '4.8',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '25': {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  '26': {'petal.length': '1.6',
#   'petal.width': '.4',
#   'sepal.length': '5',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '27': {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5.2',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  '28': {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5.2',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '29': {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '4.7',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  '30': {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '4.8',
#   'sepal.width': '3.1',
#   'variety': 'Setosa'},
#  '31': {'petal.length': '1.5',
#   'petal.width': '.4',
#   'sepal.length': '5.4',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '32': {'petal.length': '1.5',
#   'petal.width': '.1',
#   'sepal.length': '5.2',
#   'sepal.width': '4.1',
#   'variety': 'Setosa'},
#  '33': {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5.5',
#   'sepal.width': '4.2',
#   'variety': 'Setosa'},
#  '34': {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '4.9',
#   'sepal.width': '3.1',
#   'variety': 'Setosa'},
#  '35': {'petal.length': '1.2',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  '36': {'petal.length': '1.3',
#   'petal.width': '.2',
#   'sepal.length': '5.5',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  '37': {'petal.length': '1.4',
#   'petal.width': '.1',
#   'sepal.length': '4.9',
#   'sepal.width': '3.6',
#   'variety': 'Setosa'},
#  '38': {'petal.length': '1.3',
#   'petal.width': '.2',
#   'sepal.length': '4.4',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  '39': {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5.1',
#   'sepal.width': '3.4',
#   'variety': 'Setosa'},
#  '40': {'petal.length': '1.3',
#   'petal.width': '.3',
#   'sepal.length': '5',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  '41': {'petal.length': '1.3',
#   'petal.width': '.3',
#   'sepal.length': '4.5',
#   'sepal.width': '2.3',
#   'variety': 'Setosa'},
#  '42': {'petal.length': '1.3',
#   'petal.width': '.2',
#   'sepal.length': '4.4',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  '43': {'petal.length': '1.6',
#   'petal.width': '.6',
#   'sepal.length': '5',
#   'sepal.width': '3.5',
#   'variety': 'Setosa'},
#  '44': {'petal.length': '1.9',
#   'petal.width': '.4',
#   'sepal.length': '5.1',
#   'sepal.width': '3.8',
#   'variety': 'Setosa'},
#  '45': {'petal.length': '1.4',
#   'petal.width': '.3',
#   'sepal.length': '4.8',
#   'sepal.width': '3',
#   'variety': 'Setosa'},
#  '46': {'petal.length': '1.6',
#   'petal.width': '.2',
#   'sepal.length': '5.1',
#   'sepal.width': '3.8',
#   'variety': 'Setosa'},
#  '47': {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '4.6',
#   'sepal.width': '3.2',
#   'variety': 'Setosa'},
#  '48': {'petal.length': '1.5',
#   'petal.width': '.2',
#   'sepal.length': '5.3',
#   'sepal.width': '3.7',
#   'variety': 'Setosa'},
#  '49': {'petal.length': '1.4',
#   'petal.width': '.2',
#   'sepal.length': '5',
#   'sepal.width': '3.3',
#   'variety': 'Setosa'},
#  '50': {'petal.length': '4.7',
#   'petal.width': '1.4',
#   'sepal.length': '7',
#   'sepal.width': '3.2',
#   'variety': 'Versicolor'},
#  '51': {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '6.4',
#   'sepal.width': '3.2',
#   'variety': 'Versicolor'},
#  '52': {'petal.length': '4.9',
#   'petal.width': '1.5',
#   'sepal.length': '6.9',
#   'sepal.width': '3.1',
#   'variety': 'Versicolor'},
#  '53': {'petal.length': '4',
#   'petal.width': '1.3',
#   'sepal.length': '5.5',
#   'sepal.width': '2.3',
#   'variety': 'Versicolor'},
#  '54': {'petal.length': '4.6',
#   'petal.width': '1.5',
#   'sepal.length': '6.5',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  '55': {'petal.length': '4.5',
#   'petal.width': '1.3',
#   'sepal.length': '5.7',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  '56': {'petal.length': '4.7',
#   'petal.width': '1.6',
#   'sepal.length': '6.3',
#   'sepal.width': '3.3',
#   'variety': 'Versicolor'},
#  '57': {'petal.length': '3.3',
#   'petal.width': '1',
#   'sepal.length': '4.9',
#   'sepal.width': '2.4',
#   'variety': 'Versicolor'},
#  '58': {'petal.length': '4.6',
#   'petal.width': '1.3',
#   'sepal.length': '6.6',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  '59': {'petal.length': '3.9',
#   'petal.width': '1.4',
#   'sepal.length': '5.2',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  '60': {'petal.length': '3.5',
#   'petal.width': '1',
#   'sepal.length': '5',
#   'sepal.width': '2',
#   'variety': 'Versicolor'},
#  '61': {'petal.length': '4.2',
#   'petal.width': '1.5',
#   'sepal.length': '5.9',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  '62': {'petal.length': '4',
#   'petal.width': '1',
#   'sepal.length': '6',
#   'sepal.width': '2.2',
#   'variety': 'Versicolor'},
#  '63': {'petal.length': '4.7',
#   'petal.width': '1.4',
#   'sepal.length': '6.1',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  '64': {'petal.length': '3.6',
#   'petal.width': '1.3',
#   'sepal.length': '5.6',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  '65': {'petal.length': '4.4',
#   'petal.width': '1.4',
#   'sepal.length': '6.7',
#   'sepal.width': '3.1',
#   'variety': 'Versicolor'},
#  '66': {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '5.6',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  '67': {'petal.length': '4.1',
#   'petal.width': '1',
#   'sepal.length': '5.8',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  '68': {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '6.2',
#   'sepal.width': '2.2',
#   'variety': 'Versicolor'},
#  '69': {'petal.length': '3.9',
#   'petal.width': '1.1',
#   'sepal.length': '5.6',
#   'sepal.width': '2.5',
#   'variety': 'Versicolor'},
#  '70': {'petal.length': '4.8',
#   'petal.width': '1.8',
#   'sepal.length': '5.9',
#   'sepal.width': '3.2',
#   'variety': 'Versicolor'},
#  '71': {'petal.length': '4',
#   'petal.width': '1.3',
#   'sepal.length': '6.1',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  '72': {'petal.length': '4.9',
#   'petal.width': '1.5',
#   'sepal.length': '6.3',
#   'sepal.width': '2.5',
#   'variety': 'Versicolor'},
#  '73': {'petal.length': '4.7',
#   'petal.width': '1.2',
#   'sepal.length': '6.1',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  '74': {'petal.length': '4.3',
#   'petal.width': '1.3',
#   'sepal.length': '6.4',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  '75': {'petal.length': '4.4',
#   'petal.width': '1.4',
#   'sepal.length': '6.6',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  '76': {'petal.length': '4.8',
#   'petal.width': '1.4',
#   'sepal.length': '6.8',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  '77': {'petal.length': '5',
#   'petal.width': '1.7',
#   'sepal.length': '6.7',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  '78': {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '6',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  '79': {'petal.length': '3.5',
#   'petal.width': '1',
#   'sepal.length': '5.7',
#   'sepal.width': '2.6',
#   'variety': 'Versicolor'},
#  '80': {'petal.length': '3.8',
#   'petal.width': '1.1',
#   'sepal.length': '5.5',
#   'sepal.width': '2.4',
#   'variety': 'Versicolor'},
#  '81': {'petal.length': '3.7',
#   'petal.width': '1',
#   'sepal.length': '5.5',
#   'sepal.width': '2.4',
#   'variety': 'Versicolor'},
#  '82': {'petal.length': '3.9',
#   'petal.width': '1.2',
#   'sepal.length': '5.8',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  '83': {'petal.length': '5.1',
#   'petal.width': '1.6',
#   'sepal.length': '6',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  '84': {'petal.length': '4.5',
#   'petal.width': '1.5',
#   'sepal.length': '5.4',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  '85': {'petal.length': '4.5',
#   'petal.width': '1.6',
#   'sepal.length': '6',
#   'sepal.width': '3.4',
#   'variety': 'Versicolor'},
#  '86': {'petal.length': '4.7',
#   'petal.width': '1.5',
#   'sepal.length': '6.7',
#   'sepal.width': '3.1',
#   'variety': 'Versicolor'},
#  '87': {'petal.length': '4.4',
#   'petal.width': '1.3',
#   'sepal.length': '6.3',
#   'sepal.width': '2.3',
#   'variety': 'Versicolor'},
#  '88': {'petal.length': '4.1',
#   'petal.width': '1.3',
#   'sepal.length': '5.6',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  '89': {'petal.length': '4',
#   'petal.width': '1.3',
#   'sepal.length': '5.5',
#   'sepal.width': '2.5',
#   'variety': 'Versicolor'},
#  '90': {'petal.length': '4.4',
#   'petal.width': '1.2',
#   'sepal.length': '5.5',
#   'sepal.width': '2.6',
#   'variety': 'Versicolor'},
#  '91': {'petal.length': '4.6',
#   'petal.width': '1.4',
#   'sepal.length': '6.1',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  '92': {'petal.length': '4',
#   'petal.width': '1.2',
#   'sepal.length': '5.8',
#   'sepal.width': '2.6',
#   'variety': 'Versicolor'},
#  '93': {'petal.length': '3.3',
#   'petal.width': '1',
#   'sepal.length': '5',
#   'sepal.width': '2.3',
#   'variety': 'Versicolor'},
#  '94': {'petal.length': '4.2',
#   'petal.width': '1.3',
#   'sepal.length': '5.6',
#   'sepal.width': '2.7',
#   'variety': 'Versicolor'},
#  '95': {'petal.length': '4.2',
#   'petal.width': '1.2',
#   'sepal.length': '5.7',
#   'sepal.width': '3',
#   'variety': 'Versicolor'},
#  '96': {'petal.length': '4.2',
#   'petal.width': '1.3',
#   'sepal.length': '5.7',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  '97': {'petal.length': '4.3',
#   'petal.width': '1.3',
#   'sepal.length': '6.2',
#   'sepal.width': '2.9',
#   'variety': 'Versicolor'},
#  '98': {'petal.length': '3',
#   'petal.width': '1.1',
#   'sepal.length': '5.1',
#   'sepal.width': '2.5',
#   'variety': 'Versicolor'},
#  '99': {'petal.length': '4.1',
#   'petal.width': '1.3',
#   'sepal.length': '5.7',
#   'sepal.width': '2.8',
#   'variety': 'Versicolor'},
#  '100': {'petal.length': '6',
#   'petal.width': '2.5',
#   'sepal.length': '6.3',
#   'sepal.width': '3.3',
#   'variety': 'Virginica'},
#  '101': {'petal.length': '5.1',
#   'petal.width': '1.9',
#   'sepal.length': '5.8',
#   'sepal.width': '2.7',
#   'variety': 'Virginica'},
#  '102': {'petal.length': '5.9',
#   'petal.width': '2.1',
#   'sepal.length': '7.1',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '103': {'petal.length': '5.6',
#   'petal.width': '1.8',
#   'sepal.length': '6.3',
#   'sepal.width': '2.9',
#   'variety': 'Virginica'},
#  '104': {'petal.length': '5.8',
#   'petal.width': '2.2',
#   'sepal.length': '6.5',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '105': {'petal.length': '6.6',
#   'petal.width': '2.1',
#   'sepal.length': '7.6',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '106': {'petal.length': '4.5',
#   'petal.width': '1.7',
#   'sepal.length': '4.9',
#   'sepal.width': '2.5',
#   'variety': 'Virginica'},
#  '107': {'petal.length': '6.3',
#   'petal.width': '1.8',
#   'sepal.length': '7.3',
#   'sepal.width': '2.9',
#   'variety': 'Virginica'},
#  '108': {'petal.length': '5.8',
#   'petal.width': '1.8',
#   'sepal.length': '6.7',
#   'sepal.width': '2.5',
#   'variety': 'Virginica'},
#  '109': {'petal.length': '6.1',
#   'petal.width': '2.5',
#   'sepal.length': '7.2',
#   'sepal.width': '3.6',
#   'variety': 'Virginica'},
#  '110': {'petal.length': '5.1',
#   'petal.width': '2',
#   'sepal.length': '6.5',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  '111': {'petal.length': '5.3',
#   'petal.width': '1.9',
#   'sepal.length': '6.4',
#   'sepal.width': '2.7',
#   'variety': 'Virginica'},
#  '112': {'petal.length': '5.5',
#   'petal.width': '2.1',
#   'sepal.length': '6.8',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '113': {'petal.length': '5',
#   'petal.width': '2',
#   'sepal.length': '5.7',
#   'sepal.width': '2.5',
#   'variety': 'Virginica'},
#  '114': {'petal.length': '5.1',
#   'petal.width': '2.4',
#   'sepal.length': '5.8',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  '115': {'petal.length': '5.3',
#   'petal.width': '2.3',
#   'sepal.length': '6.4',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  '116': {'petal.length': '5.5',
#   'petal.width': '1.8',
#   'sepal.length': '6.5',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '117': {'petal.length': '6.7',
#   'petal.width': '2.2',
#   'sepal.length': '7.7',
#   'sepal.width': '3.8',
#   'variety': 'Virginica'},
#  '118': {'petal.length': '6.9',
#   'petal.width': '2.3',
#   'sepal.length': '7.7',
#   'sepal.width': '2.6',
#   'variety': 'Virginica'},
#  '119': {'petal.length': '5',
#   'petal.width': '1.5',
#   'sepal.length': '6',
#   'sepal.width': '2.2',
#   'variety': 'Virginica'},
#  '120': {'petal.length': '5.7',
#   'petal.width': '2.3',
#   'sepal.length': '6.9',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  '121': {'petal.length': '4.9',
#   'petal.width': '2',
#   'sepal.length': '5.6',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  '122': {'petal.length': '6.7',
#   'petal.width': '2',
#   'sepal.length': '7.7',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  '123': {'petal.length': '4.9',
#   'petal.width': '1.8',
#   'sepal.length': '6.3',
#   'sepal.width': '2.7',
#   'variety': 'Virginica'},
#  '124': {'petal.length': '5.7',
#   'petal.width': '2.1',
#   'sepal.length': '6.7',
#   'sepal.width': '3.3',
#   'variety': 'Virginica'},
#  '125': {'petal.length': '6',
#   'petal.width': '1.8',
#   'sepal.length': '7.2',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  '126': {'petal.length': '4.8',
#   'petal.width': '1.8',
#   'sepal.length': '6.2',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  '127': {'petal.length': '4.9',
#   'petal.width': '1.8',
#   'sepal.length': '6.1',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '128': {'petal.length': '5.6',
#   'petal.width': '2.1',
#   'sepal.length': '6.4',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  '129': {'petal.length': '5.8',
#   'petal.width': '1.6',
#   'sepal.length': '7.2',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '130': {'petal.length': '6.1',
#   'petal.width': '1.9',
#   'sepal.length': '7.4',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  '131': {'petal.length': '6.4',
#   'petal.width': '2',
#   'sepal.length': '7.9',
#   'sepal.width': '3.8',
#   'variety': 'Virginica'},
#  '132': {'petal.length': '5.6',
#   'petal.width': '2.2',
#   'sepal.length': '6.4',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  '133': {'petal.length': '5.1',
#   'petal.width': '1.5',
#   'sepal.length': '6.3',
#   'sepal.width': '2.8',
#   'variety': 'Virginica'},
#  '134': {'petal.length': '5.6',
#   'petal.width': '1.4',
#   'sepal.length': '6.1',
#   'sepal.width': '2.6',
#   'variety': 'Virginica'},
#  '135': {'petal.length': '6.1',
#   'petal.width': '2.3',
#   'sepal.length': '7.7',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '136': {'petal.length': '5.6',
#   'petal.width': '2.4',
#   'sepal.length': '6.3',
#   'sepal.width': '3.4',
#   'variety': 'Virginica'},
#  '137': {'petal.length': '5.5',
#   'petal.width': '1.8',
#   'sepal.length': '6.4',
#   'sepal.width': '3.1',
#   'variety': 'Virginica'},
#  '138': {'petal.length': '4.8',
#   'petal.width': '1.8',
#   'sepal.length': '6',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '139': {'petal.length': '5.4',
#   'petal.width': '2.1',
#   'sepal.length': '6.9',
#   'sepal.width': '3.1',
#   'variety': 'Virginica'},
#  '140': {'petal.length': '5.6',
#   'petal.width': '2.4',
#   'sepal.length': '6.7',
#   'sepal.width': '3.1',
#   'variety': 'Virginica'},
#  '141': {'petal.length': '5.1',
#   'petal.width': '2.3',
#   'sepal.length': '6.9',
#   'sepal.width': '3.1',
#   'variety': 'Virginica'},
#  '142': {'petal.length': '5.1',
#   'petal.width': '1.9',
#   'sepal.length': '5.8',
#   'sepal.width': '2.7',
#   'variety': 'Virginica'},
#  '143': {'petal.length': '5.9',
#   'petal.width': '2.3',
#   'sepal.length': '6.8',
#   'sepal.width': '3.2',
#   'variety': 'Virginica'},
#  '144': {'petal.length': '5.7',
#   'petal.width': '2.5',
#   'sepal.length': '6.7',
#   'sepal.width': '3.3',
#   'variety': 'Virginica'},
#  '145': {'petal.length': '5.2',
#   'petal.width': '2.3',
#   'sepal.length': '6.7',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '146': {'petal.length': '5',
#   'petal.width': '1.9',
#   'sepal.length': '6.3',
#   'sepal.width': '2.5',
#   'variety': 'Virginica'},
#  '147': {'petal.length': '5.2',
#   'petal.width': '2',
#   'sepal.length': '6.5',
#   'sepal.width': '3',
#   'variety': 'Virginica'},
#  '148': {'petal.length': '5.4',
#   'petal.width': '2.3',
#   'sepal.length': '6.2',
#   'sepal.width': '3.4',
#   'variety': 'Virginica'},
#  '149': {'petal.length': '5.1',
#   'petal.width': '1.8',
#   'sepal.length': '5.9',
#   'sepal.width': '3',
#   'variety': 'Virginica'}}

# %% [markdown]
# # Yet Another Markup Language (YAML)
#
# [Yet Another Markup Language](https://en.wikipedia.org/wiki/YAML) is a very versatile data format used in variety of applications. It is not as widely used as JSON or XML. Here is a sample:

# %%
with open('./data/example3.yml') as file:
    yml = file.read()
    
print(yml)
# Out:
# ---
# receipts:
#   - receipt:     Oz-Ware Purchase Invoice
#     date:        2012-08-06
#     customer:
#         first_name:   Dorothy
#         family_name:  Gale
#
#     items:
#       - part_no:   A4786
#         descrip:   Water Bucket (Filled)
#         price:     1.47
#         quantity:  4
#
#       - part_no:   E1628
#         descrip:   High Heeled "Ruby" Slippers
#         size:      8
#         price:     133.7
#         quantity:  1
#
#     bill-to:  &id001
#         street: |
#             123 Tornado Alley
#             Suite 16
#         city:   East Centerville
#         state:  KS
#
#     ship-to:  *id001
#
#     specialDelivery:  >
#       Follow the Yellow Brick
#       Road to the Emerald City.
#       Pay no attention to the
#       man behind the curtain.
#   - receipt:    Oz-Ware Purchase Invoice
#     date:       2020-02-29
#     customer:
#         first_name:   Man
#         family_name:  Tin
#
#     items:
#       - part_no:  C9090
#         descrip:  Heart
#         price:    2.0
#         quantity: 1
#
#     bill-to: *id001
#     specialDelivery: >
#       Find Dorothy.
# ...

# %%
with open('./data/example3.yml') as file:
    yml = yaml.safe_load(file)
    
yml
# Out:
# {'receipts': [{'receipt': 'Oz-Ware Purchase Invoice',
#    'date': datetime.date(2012, 8, 6),
#    'customer': {'first_name': 'Dorothy', 'family_name': 'Gale'},
#    'items': [{'part_no': 'A4786',
#      'descrip': 'Water Bucket (Filled)',
#      'price': 1.47,
#      'quantity': 4},
#     {'part_no': 'E1628',
#      'descrip': 'High Heeled "Ruby" Slippers',
#      'size': 8,
#      'price': 133.7,
#      'quantity': 1}],
#    'bill-to': {'street': '123 Tornado Alley\nSuite 16\n',
#     'city': 'East Centerville',
#     'state': 'KS'},
#    'ship-to': {'street': '123 Tornado Alley\nSuite 16\n',
#     'city': 'East Centerville',
#     'state': 'KS'},
#    'specialDelivery': 'Follow the Yellow Brick Road to the Emerald City. Pay no attention to the man behind the curtain.\n'},
#   {'receipt': 'Oz-Ware Purchase Invoice',
#    'date': datetime.date(2020, 2, 29),
#    'customer': {'first_name': 'Man', 'family_name': 'Tin'},
#    'items': [{'part_no': 'C9090',
#      'descrip': 'Heart',
#      'price': 2.0,
#      'quantity': 1}],
#    'bill-to': {'street': '123 Tornado Alley\nSuite 16\n',
#     'city': 'East Centerville',
#     'state': 'KS'},
#    'specialDelivery': 'Find Dorothy.\n'}]}

# %%
yml['receipts'][0]['customer']['first_name']
# Out:
# 'Dorothy'

# %% [markdown]
# # Extensible Markup Language
#
#
# [XML](https://en.wikipedia.org/wiki/XML) is a complicated data and markup language. It basically assume the structure of the data/document is a tree.
#
# ![XML](./images/Example-of-XML-document-and-XML-tree-representation.png)
#
# [Source](https://www.researchgate.net/figure/Example-of-XML-document-and-XML-tree-representation_fig1_315998361)
#
# Here is a hand-encoded dictionary version of the XML data you see in the picture:

# %%
xmlString = """
<library>
    <book>
       <year>1990</year>
       <title>XML Labeling</title>
       <publisher>Smart Publ.</publisher>
    </book>
    <magazine>
       <issue>1</issue>
       <title>Technology</title>
       <publisher>Ideal Publ.</publisher>
    </magazine>
</library>
"""

xml = ET.fromstring(xmlString)
xml
# Out:
# <Element 'library' at 0x7fe504c9ffb0>

# %%
{'library': 
  {'book': {'year': 1990, 'title': 'XML Labeling', 'publisher': 'Smart Publ.'},
   'magazine' : {'issue': 1, 'title': 'Tecnology', 'publisher': 'Ideal Publ'}}
}
# Out:
# {'library': {'book': {'year': 1990,
#    'title': 'XML Labeling',
#    'publisher': 'Smart Publ.'},
#   'magazine': {'issue': 1, 'title': 'Tecnology', 'publisher': 'Ideal Publ'}}}

# %% [markdown]
# There are many variations of XML. Most famous and widely used variation of XML is [Hypertext Markup Language (HTML)](https://en.wikipedia.org/wiki/HTML). XML requires its own lecture (which I am not going to do!). The safest method to deal with XML via python is to convert it into a dictionary (or a hash-map) via [xmltodict](https://github.com/martinblech/xmltodict) library.
#
# Here is an example:

# %%
#with urlopen("https://stats.oecd.org/restsdmx/sdmx.ashx/GetData/WEALTH/AUS+AUT+BEL+CAN+CHL+DNK+EST+FIN+FRA+DEU+GRC+HUN+IRL+ITA+JPN+KOR+LVA+LTU+LUX+NLD+NZL+NOR+POL+PRT+SVK+SVN+ESP+GBR+USA/all?startTime=2010&endTime=2022") as url:
with open('./data/DataCompact.xml') as url:
    raw = parse(url.read(),encoding='utf-8')
    
raw
# Out:
# {'message:CompactData': {'@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   '@xmlns:common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   '@xmlns:compact': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/compact',
#   '@xmlns:OECD': 'http://oecd.stat.org/Data',
#   '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   '@xsi:schemaLocation': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message http://www.sdmx.org/docs/2_0/SDMXMessage.xsd http://oecd.stat.org/Data https://stats-1.oecd.org/RestSDMX/sdmx.ashx/GetSchema/EDU_GRAD_INST',
#   '@xmlns:message': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'Header': {'ID': 'none',
#    'Test': 'false',
#    'Truncated': 'false',
#    'Prepared': '2022-10-07T08:28:55',
#    'Sender': {'@id': 'OECD',
#     'Name': [{'@xml:lang': 'en',
#       '#text': 'Organisation for Economic Co-operation and Development'},
#      {'@xml:lang': 'fr',
#       '#text': 'Organisation de coopération et de développement économiques'}]}},
#   'OECD:DataSet': {'@keyFamilyURI': 'https://stats-1.oecd.org/RestSDMX/sdmx.ashx/GetKeyFamily/EDU_GRAD_INST',
#    '@xmlns:OECD': 'http://oecd.stat.org/Data',
#    'OECD:Series': [{'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '222277'},
#       {'@TIME': '2014', '@OBS_VALUE': '235756'},
#       {'@TIME': '2015', '@OBS_VALUE': '199425'},
#       {'@TIME': '2016', '@OBS_VALUE': '181637'},
#       {'@TIME': '2017', '@OBS_VALUE': '170966'},
#       {'@TIME': '2018', '@OBS_VALUE': '195256'},
#       {'@TIME': '2019', '@OBS_VALUE': '195508'},
#       {'@TIME': '2020', '@OBS_VALUE': '195206'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '209808'},
#       {'@TIME': '2014', '@OBS_VALUE': '241598'},
#       {'@TIME': '2015', '@OBS_VALUE': '198373'},
#       {'@TIME': '2016', '@OBS_VALUE': '193592'},
#       {'@TIME': '2017', '@OBS_VALUE': '175372'},
#       {'@TIME': '2018', '@OBS_VALUE': '198935'},
#       {'@TIME': '2019', '@OBS_VALUE': '196122'},
#       {'@TIME': '2020', '@OBS_VALUE': '188457'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '432085'},
#       {'@TIME': '2014', '@OBS_VALUE': '477354'},
#       {'@TIME': '2015', '@OBS_VALUE': '397798'},
#       {'@TIME': '2016', '@OBS_VALUE': '375229'},
#       {'@TIME': '2017', '@OBS_VALUE': '346338'},
#       {'@TIME': '2018', '@OBS_VALUE': '394191'},
#       {'@TIME': '2019', '@OBS_VALUE': '391630'},
#       {'@TIME': '2020', '@OBS_VALUE': '383663'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '128291'},
#       {'@TIME': '2014', '@OBS_VALUE': '140173'},
#       {'@TIME': '2015', '@OBS_VALUE': '86729'},
#       {'@TIME': '2016', '@OBS_VALUE': '79567'},
#       {'@TIME': '2017', '@OBS_VALUE': '77326'},
#       {'@TIME': '2018', '@OBS_VALUE': '76721'},
#       {'@TIME': '2019', '@OBS_VALUE': '93294'},
#       {'@TIME': '2020', '@OBS_VALUE': '92329'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '121469'},
#       {'@TIME': '2014', '@OBS_VALUE': '142610'},
#       {'@TIME': '2015', '@OBS_VALUE': '85537'},
#       {'@TIME': '2016', '@OBS_VALUE': '82105'},
#       {'@TIME': '2017', '@OBS_VALUE': '76823'},
#       {'@TIME': '2018', '@OBS_VALUE': '75933'},
#       {'@TIME': '2019', '@OBS_VALUE': '87860'},
#       {'@TIME': '2020', '@OBS_VALUE': '86349'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '249760'},
#       {'@TIME': '2014', '@OBS_VALUE': '282783'},
#       {'@TIME': '2015', '@OBS_VALUE': '172266'},
#       {'@TIME': '2016', '@OBS_VALUE': '161672'},
#       {'@TIME': '2017', '@OBS_VALUE': '154149'},
#       {'@TIME': '2018', '@OBS_VALUE': '152654'},
#       {'@TIME': '2019', '@OBS_VALUE': '181154'},
#       {'@TIME': '2020', '@OBS_VALUE': '178678'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '93986'},
#       {'@TIME': '2014', '@OBS_VALUE': '95583'},
#       {'@TIME': '2015', '@OBS_VALUE': '112696'},
#       {'@TIME': '2016', '@OBS_VALUE': '102070'},
#       {'@TIME': '2017', '@OBS_VALUE': '93640'},
#       {'@TIME': '2018', '@OBS_VALUE': '118535'},
#       {'@TIME': '2019', '@OBS_VALUE': '102214'},
#       {'@TIME': '2020', '@OBS_VALUE': '102877'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '88339'},
#       {'@TIME': '2014', '@OBS_VALUE': '98988'},
#       {'@TIME': '2015', '@OBS_VALUE': '112836'},
#       {'@TIME': '2016', '@OBS_VALUE': '111487'},
#       {'@TIME': '2017', '@OBS_VALUE': '98549'},
#       {'@TIME': '2018', '@OBS_VALUE': '123002'},
#       {'@TIME': '2019', '@OBS_VALUE': '108262'},
#       {'@TIME': '2020', '@OBS_VALUE': '102108'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '182325'},
#       {'@TIME': '2014', '@OBS_VALUE': '194571'},
#       {'@TIME': '2015', '@OBS_VALUE': '225532'},
#       {'@TIME': '2016', '@OBS_VALUE': '213557'},
#       {'@TIME': '2017', '@OBS_VALUE': '192189'},
#       {'@TIME': '2018', '@OBS_VALUE': '241537'},
#       {'@TIME': '2019', '@OBS_VALUE': '210476'},
#       {'@TIME': '2020', '@OBS_VALUE': '204985'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_3',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '73345'},
#       {'@TIME': '2014', '@OBS_VALUE': '79143'},
#       {'@TIME': '2015', '@OBS_VALUE': '37395'},
#       {'@TIME': '2016', '@OBS_VALUE': '30549'},
#       {'@TIME': '2017', '@OBS_VALUE': '21179'},
#       {'@TIME': '2018', '@OBS_VALUE': '52686'},
#       {'@TIME': '2019', '@OBS_VALUE': '61577'},
#       {'@TIME': '2020', '@OBS_VALUE': '64287'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '58016'},
#       {'@TIME': '2014', '@OBS_VALUE': '64272'},
#       {'@TIME': '2015', '@OBS_VALUE': '34431'},
#       {'@TIME': '2016', '@OBS_VALUE': '31874'},
#       {'@TIME': '2017', '@OBS_VALUE': '21401'},
#       {'@TIME': '2018', '@OBS_VALUE': '53558'},
#       {'@TIME': '2019', '@OBS_VALUE': '51265'},
#       {'@TIME': '2020', '@OBS_VALUE': '54827'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '131361'},
#       {'@TIME': '2014', '@OBS_VALUE': '143415'},
#       {'@TIME': '2015', '@OBS_VALUE': '71826'},
#       {'@TIME': '2016', '@OBS_VALUE': '62423'},
#       {'@TIME': '2017', '@OBS_VALUE': '42580'},
#       {'@TIME': '2018', '@OBS_VALUE': '106244'},
#       {'@TIME': '2019', '@OBS_VALUE': '112842'},
#       {'@TIME': '2020', '@OBS_VALUE': '119114'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '48756'},
#       {'@TIME': '2014', '@OBS_VALUE': '53400'},
#       {'@TIME': '2015', '@OBS_VALUE': '13516'},
#       {'@TIME': '2016', '@OBS_VALUE': '10409'},
#       {'@TIME': '2017', '@OBS_VALUE': '6046'},
#       {'@TIME': '2018', '@OBS_VALUE': '6256'},
#       {'@TIME': '2019', '@OBS_VALUE': '20664'},
#       {'@TIME': '2020', '@OBS_VALUE': '19262'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '37402'},
#       {'@TIME': '2014', '@OBS_VALUE': '41335'},
#       {'@TIME': '2015', '@OBS_VALUE': '11337'},
#       {'@TIME': '2016', '@OBS_VALUE': '8130'},
#       {'@TIME': '2017', '@OBS_VALUE': '4343'},
#       {'@TIME': '2018', '@OBS_VALUE': '5113'},
#       {'@TIME': '2019', '@OBS_VALUE': '14383'},
#       {'@TIME': '2020', '@OBS_VALUE': '12970'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '86158'},
#       {'@TIME': '2014', '@OBS_VALUE': '94735'},
#       {'@TIME': '2015', '@OBS_VALUE': '24853'},
#       {'@TIME': '2016', '@OBS_VALUE': '18539'},
#       {'@TIME': '2017', '@OBS_VALUE': '10389'},
#       {'@TIME': '2018', '@OBS_VALUE': '11369'},
#       {'@TIME': '2019', '@OBS_VALUE': '35047'},
#       {'@TIME': '2020', '@OBS_VALUE': '32232'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '24589'},
#       {'@TIME': '2014', '@OBS_VALUE': '25743'},
#       {'@TIME': '2015', '@OBS_VALUE': '23879'},
#       {'@TIME': '2016', '@OBS_VALUE': '20140'},
#       {'@TIME': '2017', '@OBS_VALUE': '15133'},
#       {'@TIME': '2018', '@OBS_VALUE': '46430'},
#       {'@TIME': '2019', '@OBS_VALUE': '40913'},
#       {'@TIME': '2020', '@OBS_VALUE': '45025'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '20614'},
#       {'@TIME': '2014', '@OBS_VALUE': '22937'},
#       {'@TIME': '2015', '@OBS_VALUE': '23094'},
#       {'@TIME': '2016', '@OBS_VALUE': '23744'},
#       {'@TIME': '2017', '@OBS_VALUE': '17058'},
#       {'@TIME': '2018', '@OBS_VALUE': '48445'},
#       {'@TIME': '2019', '@OBS_VALUE': '36882'},
#       {'@TIME': '2020', '@OBS_VALUE': '41857'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '45203'},
#       {'@TIME': '2014', '@OBS_VALUE': '48680'},
#       {'@TIME': '2015', '@OBS_VALUE': '46973'},
#       {'@TIME': '2016', '@OBS_VALUE': '43884'},
#       {'@TIME': '2017', '@OBS_VALUE': '32191'},
#       {'@TIME': '2018', '@OBS_VALUE': '94875'},
#       {'@TIME': '2019', '@OBS_VALUE': '77795'},
#       {'@TIME': '2020', '@OBS_VALUE': '86882'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_4',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '59139'},
#       {'@TIME': '2014', '@OBS_VALUE': '69056'},
#       {'@TIME': '2015', '@OBS_VALUE': '35785'},
#       {'@TIME': '2016', '@OBS_VALUE': '29808'},
#       {'@TIME': '2017', '@OBS_VALUE': '30951'},
#       {'@TIME': '2018', '@OBS_VALUE': '70816'},
#       {'@TIME': '2019', '@OBS_VALUE': '88228'},
#       {'@TIME': '2020', '@OBS_VALUE': '78091'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '44176'},
#       {'@TIME': '2014', '@OBS_VALUE': '49117'},
#       {'@TIME': '2015', '@OBS_VALUE': '23591'},
#       {'@TIME': '2016', '@OBS_VALUE': '21030'},
#       {'@TIME': '2017', '@OBS_VALUE': '20141'},
#       {'@TIME': '2018', '@OBS_VALUE': '50761'},
#       {'@TIME': '2019', '@OBS_VALUE': '64423'},
#       {'@TIME': '2020', '@OBS_VALUE': '59629'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '103315'},
#       {'@TIME': '2014', '@OBS_VALUE': '118173'},
#       {'@TIME': '2015', '@OBS_VALUE': '59376'},
#       {'@TIME': '2016', '@OBS_VALUE': '50838'},
#       {'@TIME': '2017', '@OBS_VALUE': '51092'},
#       {'@TIME': '2018', '@OBS_VALUE': '121577'},
#       {'@TIME': '2019', '@OBS_VALUE': '152651'},
#       {'@TIME': '2020', '@OBS_VALUE': '137720'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '42158'},
#       {'@TIME': '2014', '@OBS_VALUE': '50978'},
#       {'@TIME': '2015', '@OBS_VALUE': '17427'},
#       {'@TIME': '2016', '@OBS_VALUE': '13369'},
#       {'@TIME': '2017', '@OBS_VALUE': '11670'},
#       {'@TIME': '2018', '@OBS_VALUE': '12570'},
#       {'@TIME': '2019', '@OBS_VALUE': '29402'},
#       {'@TIME': '2020', '@OBS_VALUE': '24915'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '31014'},
#       {'@TIME': '2014', '@OBS_VALUE': '35836'},
#       {'@TIME': '2015', '@OBS_VALUE': '11407'},
#       {'@TIME': '2016', '@OBS_VALUE': '9344'},
#       {'@TIME': '2017', '@OBS_VALUE': '8115'},
#       {'@TIME': '2018', '@OBS_VALUE': '9074'},
#       {'@TIME': '2019', '@OBS_VALUE': '19191'},
#       {'@TIME': '2020', '@OBS_VALUE': '17334'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '73172'},
#       {'@TIME': '2014', '@OBS_VALUE': '86814'},
#       {'@TIME': '2015', '@OBS_VALUE': '28834'},
#       {'@TIME': '2016', '@OBS_VALUE': '22713'},
#       {'@TIME': '2017', '@OBS_VALUE': '19785'},
#       {'@TIME': '2018', '@OBS_VALUE': '21644'},
#       {'@TIME': '2019', '@OBS_VALUE': '48593'},
#       {'@TIME': '2020', '@OBS_VALUE': '42249'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '16981'},
#       {'@TIME': '2014', '@OBS_VALUE': '18078'},
#       {'@TIME': '2015', '@OBS_VALUE': '18358'},
#       {'@TIME': '2016', '@OBS_VALUE': '16439'},
#       {'@TIME': '2017', '@OBS_VALUE': '19281'},
#       {'@TIME': '2018', '@OBS_VALUE': '58246'},
#       {'@TIME': '2019', '@OBS_VALUE': '58826'},
#       {'@TIME': '2020', '@OBS_VALUE': '53176'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '13162'},
#       {'@TIME': '2014', '@OBS_VALUE': '13281'},
#       {'@TIME': '2015', '@OBS_VALUE': '12184'},
#       {'@TIME': '2016', '@OBS_VALUE': '11686'},
#       {'@TIME': '2017', '@OBS_VALUE': '12026'},
#       {'@TIME': '2018', '@OBS_VALUE': '41687'},
#       {'@TIME': '2019', '@OBS_VALUE': '45232'},
#       {'@TIME': '2020', '@OBS_VALUE': '42295'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '30143'},
#       {'@TIME': '2014', '@OBS_VALUE': '31359'},
#       {'@TIME': '2015', '@OBS_VALUE': '30542'},
#       {'@TIME': '2016', '@OBS_VALUE': '28125'},
#       {'@TIME': '2017', '@OBS_VALUE': '31307'},
#       {'@TIME': '2018', '@OBS_VALUE': '99933'},
#       {'@TIME': '2019', '@OBS_VALUE': '104058'},
#       {'@TIME': '2020', '@OBS_VALUE': '95471'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '131130'},
#       {'@TIME': '2014', '@OBS_VALUE': '132243'},
#       {'@TIME': '2015', '@OBS_VALUE': '128859'},
#       {'@TIME': '2016', '@OBS_VALUE': '131875'},
#       {'@TIME': '2017', '@OBS_VALUE': '133373'},
#       {'@TIME': '2018', '@OBS_VALUE': '140168'},
#       {'@TIME': '2019', '@OBS_VALUE': '141820'},
#       {'@TIME': '2020', '@OBS_VALUE': '139702'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '90776'},
#       {'@TIME': '2014', '@OBS_VALUE': '90676'},
#       {'@TIME': '2015', '@OBS_VALUE': '89754'},
#       {'@TIME': '2016', '@OBS_VALUE': '92336'},
#       {'@TIME': '2017', '@OBS_VALUE': '92792'},
#       {'@TIME': '2018', '@OBS_VALUE': '95392'},
#       {'@TIME': '2019', '@OBS_VALUE': '96509'},
#       {'@TIME': '2020', '@OBS_VALUE': '97479'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '221906'},
#       {'@TIME': '2014', '@OBS_VALUE': '222919'},
#       {'@TIME': '2015', '@OBS_VALUE': '218613'},
#       {'@TIME': '2016', '@OBS_VALUE': '224211'},
#       {'@TIME': '2017', '@OBS_VALUE': '226165'},
#       {'@TIME': '2018', '@OBS_VALUE': '235560'},
#       {'@TIME': '2019', '@OBS_VALUE': '238329'},
#       {'@TIME': '2020', '@OBS_VALUE': '237181'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '124727'},
#       {'@TIME': '2014', '@OBS_VALUE': '126088'},
#       {'@TIME': '2015', '@OBS_VALUE': '120261'},
#       {'@TIME': '2016', '@OBS_VALUE': '121214'},
#       {'@TIME': '2017', '@OBS_VALUE': '122606'},
#       {'@TIME': '2018', '@OBS_VALUE': '126556'},
#       {'@TIME': '2019', '@OBS_VALUE': '129135'},
#       {'@TIME': '2020', '@OBS_VALUE': '126450'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '85628'},
#       {'@TIME': '2014', '@OBS_VALUE': '85687'},
#       {'@TIME': '2015', '@OBS_VALUE': '83574'},
#       {'@TIME': '2016', '@OBS_VALUE': '84262'},
#       {'@TIME': '2017', '@OBS_VALUE': '85104'},
#       {'@TIME': '2018', '@OBS_VALUE': '86706'},
#       {'@TIME': '2019', '@OBS_VALUE': '87298'},
#       {'@TIME': '2020', '@OBS_VALUE': '87718'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '210355'},
#       {'@TIME': '2014', '@OBS_VALUE': '211775'},
#       {'@TIME': '2015', '@OBS_VALUE': '203835'},
#       {'@TIME': '2016', '@OBS_VALUE': '205476'},
#       {'@TIME': '2017', '@OBS_VALUE': '207710'},
#       {'@TIME': '2018', '@OBS_VALUE': '213262'},
#       {'@TIME': '2019', '@OBS_VALUE': '216433'},
#       {'@TIME': '2020', '@OBS_VALUE': '214168'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '6403'},
#       {'@TIME': '2014', '@OBS_VALUE': '6155'},
#       {'@TIME': '2015', '@OBS_VALUE': '8598'},
#       {'@TIME': '2016', '@OBS_VALUE': '10661'},
#       {'@TIME': '2017', '@OBS_VALUE': '10767'},
#       {'@TIME': '2018', '@OBS_VALUE': '13612'},
#       {'@TIME': '2019', '@OBS_VALUE': '12685'},
#       {'@TIME': '2020', '@OBS_VALUE': '13252'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '5148'},
#       {'@TIME': '2014', '@OBS_VALUE': '4989'},
#       {'@TIME': '2015', '@OBS_VALUE': '6180'},
#       {'@TIME': '2016', '@OBS_VALUE': '8074'},
#       {'@TIME': '2017', '@OBS_VALUE': '7688'},
#       {'@TIME': '2018', '@OBS_VALUE': '8686'},
#       {'@TIME': '2019', '@OBS_VALUE': '9211'},
#       {'@TIME': '2020', '@OBS_VALUE': '9761'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '11551'},
#       {'@TIME': '2014', '@OBS_VALUE': '11144'},
#       {'@TIME': '2015', '@OBS_VALUE': '14778'},
#       {'@TIME': '2016', '@OBS_VALUE': '18735'},
#       {'@TIME': '2017', '@OBS_VALUE': '18455'},
#       {'@TIME': '2018', '@OBS_VALUE': '22298'},
#       {'@TIME': '2019', '@OBS_VALUE': '21896'},
#       {'@TIME': '2020', '@OBS_VALUE': '23013'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '37179'},
#       {'@TIME': '2014', '@OBS_VALUE': '39579'},
#       {'@TIME': '2015', '@OBS_VALUE': '41514'},
#       {'@TIME': '2016', '@OBS_VALUE': '42515'},
#       {'@TIME': '2017', '@OBS_VALUE': '46516'},
#       {'@TIME': '2018', '@OBS_VALUE': '53596'},
#       {'@TIME': '2019', '@OBS_VALUE': '58325'},
#       {'@TIME': '2020', '@OBS_VALUE': '58680'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '31121'},
#       {'@TIME': '2014', '@OBS_VALUE': '33771'},
#       {'@TIME': '2015', '@OBS_VALUE': '35579'},
#       {'@TIME': '2016', '@OBS_VALUE': '37241'},
#       {'@TIME': '2017', '@OBS_VALUE': '39982'},
#       {'@TIME': '2018', '@OBS_VALUE': '47125'},
#       {'@TIME': '2019', '@OBS_VALUE': '51318'},
#       {'@TIME': '2020', '@OBS_VALUE': '52641'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '68300'},
#       {'@TIME': '2014', '@OBS_VALUE': '73350'},
#       {'@TIME': '2015', '@OBS_VALUE': '77093'},
#       {'@TIME': '2016', '@OBS_VALUE': '79756'},
#       {'@TIME': '2017', '@OBS_VALUE': '86498'},
#       {'@TIME': '2018', '@OBS_VALUE': '100721'},
#       {'@TIME': '2019', '@OBS_VALUE': '109643'},
#       {'@TIME': '2020', '@OBS_VALUE': '111321'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '36361'},
#       {'@TIME': '2014', '@OBS_VALUE': '37879'},
#       {'@TIME': '2015', '@OBS_VALUE': '39251'},
#       {'@TIME': '2016', '@OBS_VALUE': '39762'},
#       {'@TIME': '2017', '@OBS_VALUE': '42800'},
#       {'@TIME': '2018', '@OBS_VALUE': '47993'},
#       {'@TIME': '2019', '@OBS_VALUE': '52727'},
#       {'@TIME': '2020', '@OBS_VALUE': '52028'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '30010'},
#       {'@TIME': '2014', '@OBS_VALUE': '31881'},
#       {'@TIME': '2015', '@OBS_VALUE': '33118'},
#       {'@TIME': '2016', '@OBS_VALUE': '34227'},
#       {'@TIME': '2017', '@OBS_VALUE': '35721'},
#       {'@TIME': '2018', '@OBS_VALUE': '40805'},
#       {'@TIME': '2019', '@OBS_VALUE': '44974'},
#       {'@TIME': '2020', '@OBS_VALUE': '45531'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '66371'},
#       {'@TIME': '2014', '@OBS_VALUE': '69760'},
#       {'@TIME': '2015', '@OBS_VALUE': '72369'},
#       {'@TIME': '2016', '@OBS_VALUE': '73989'},
#       {'@TIME': '2017', '@OBS_VALUE': '78521'},
#       {'@TIME': '2018', '@OBS_VALUE': '88798'},
#       {'@TIME': '2019', '@OBS_VALUE': '97701'},
#       {'@TIME': '2020', '@OBS_VALUE': '97559'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '818'},
#       {'@TIME': '2014', '@OBS_VALUE': '1700'},
#       {'@TIME': '2015', '@OBS_VALUE': '2263'},
#       {'@TIME': '2016', '@OBS_VALUE': '2753'},
#       {'@TIME': '2017', '@OBS_VALUE': '3716'},
#       {'@TIME': '2018', '@OBS_VALUE': '5603'},
#       {'@TIME': '2019', '@OBS_VALUE': '5598'},
#       {'@TIME': '2020', '@OBS_VALUE': '6652'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '1111'},
#       {'@TIME': '2014', '@OBS_VALUE': '1890'},
#       {'@TIME': '2015', '@OBS_VALUE': '2461'},
#       {'@TIME': '2016', '@OBS_VALUE': '3014'},
#       {'@TIME': '2017', '@OBS_VALUE': '4261'},
#       {'@TIME': '2018', '@OBS_VALUE': '6320'},
#       {'@TIME': '2019', '@OBS_VALUE': '6344'},
#       {'@TIME': '2020', '@OBS_VALUE': '7110'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '1929'},
#       {'@TIME': '2014', '@OBS_VALUE': '3590'},
#       {'@TIME': '2015', '@OBS_VALUE': '4724'},
#       {'@TIME': '2016', '@OBS_VALUE': '5767'},
#       {'@TIME': '2017', '@OBS_VALUE': '7977'},
#       {'@TIME': '2018', '@OBS_VALUE': '11923'},
#       {'@TIME': '2019', '@OBS_VALUE': '11942'},
#       {'@TIME': '2020', '@OBS_VALUE': '13762'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_7',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'k'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_746_756_766',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '21659'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_746_756_766',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '20524'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_746_756_766',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '42183'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'AUS',
#      '@SEX': 'F',
# ...
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV_IND',
#      '@EDUCATION_LEV': 'ISCED11_5',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '31538'},
#       {'@TIME': '2014', '@OBS_VALUE': '31093'},
#       {'@TIME': '2015', '@OBS_VALUE': '30402'},
#       {'@TIME': '2016', '@OBS_VALUE': '31824'},
#       {'@TIME': '2017', '@OBS_VALUE': '29472'},
#       {'@TIME': '2018', '@OBS_VALUE': '28295'},
#       {'@TIME': '2019', '@OBS_VALUE': '28703'},
#       {'@TIME': '2020', '@OBS_VALUE': '27289'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '21856'},
#       {'@TIME': '2014', '@OBS_VALUE': '22886'},
#       {'@TIME': '2015', '@OBS_VALUE': '21895'},
#       {'@TIME': '2016', '@OBS_VALUE': '21299'},
#       {'@TIME': '2017', '@OBS_VALUE': '20661'},
#       {'@TIME': '2018', '@OBS_VALUE': '19709'},
#       {'@TIME': '2019', '@OBS_VALUE': '19627'},
#       {'@TIME': '2020', '@OBS_VALUE': '19579'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_T',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '53394'},
#       {'@TIME': '2014', '@OBS_VALUE': '53979'},
#       {'@TIME': '2015', '@OBS_VALUE': '52297'},
#       {'@TIME': '2016', '@OBS_VALUE': '53123'},
#       {'@TIME': '2017', '@OBS_VALUE': '50133'},
#       {'@TIME': '2018', '@OBS_VALUE': '48004'},
#       {'@TIME': '2019', '@OBS_VALUE': '48330'},
#       {'@TIME': '2020', '@OBS_VALUE': '46868'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '31538'},
#       {'@TIME': '2014', '@OBS_VALUE': '31093'},
#       {'@TIME': '2015', '@OBS_VALUE': '30402'},
#       {'@TIME': '2016', '@OBS_VALUE': '31824'},
#       {'@TIME': '2017', '@OBS_VALUE': '29472'},
#       {'@TIME': '2018', '@OBS_VALUE': '28295'},
#       {'@TIME': '2019', '@OBS_VALUE': '28703'},
#       {'@TIME': '2020', '@OBS_VALUE': '27289'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '21856'},
#       {'@TIME': '2014', '@OBS_VALUE': '22886'},
#       {'@TIME': '2015', '@OBS_VALUE': '21895'},
#       {'@TIME': '2016', '@OBS_VALUE': '21299'},
#       {'@TIME': '2017', '@OBS_VALUE': '20661'},
#       {'@TIME': '2018', '@OBS_VALUE': '19709'},
#       {'@TIME': '2019', '@OBS_VALUE': '19627'},
#       {'@TIME': '2020', '@OBS_VALUE': '19579'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PUB',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': '53394'},
#       {'@TIME': '2014', '@OBS_VALUE': '53979'},
#       {'@TIME': '2015', '@OBS_VALUE': '52297'},
#       {'@TIME': '2016', '@OBS_VALUE': '53123'},
#       {'@TIME': '2017', '@OBS_VALUE': '50133'},
#       {'@TIME': '2018', '@OBS_VALUE': '48004'},
#       {'@TIME': '2019', '@OBS_VALUE': '48330'},
#       {'@TIME': '2020', '@OBS_VALUE': '46868'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'M',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': '_T',
#      '@REF_SECTOR': 'INST_PRIV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     {'@COUNTRY': 'GRC',
#      '@SEX': 'F',
#      '@REF_SECTOR': 'INST_PRIV_GOV',
#      '@EDUCATION_LEV': 'ISCED11_6',
#      '@TIME_FORMAT': 'P1Y',
#      'OECD:Obs': [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#       {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}]},
#     ...],
#    'OECD:Annotations': {'common:Annotation': [{'@xmlns:common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#       'common:AnnotationTitle': 'Copyright OECD - All rights reserved'},
#      {'@xmlns:common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#       'common:AnnotationTitle': 'Terms and Conditions',
#       'common:AnnotationURL': 'http://www.oecd.org/termsandconditions/'},
#      {'@xmlns:common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#       'common:AnnotationTitle': 'Privacy Policy',
#       'common:AnnotationURL': 'http://www.oecd.org/privacy/'},
#      {'@xmlns:common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#       'common:AnnotationTitle': 'MyOECD',
#       'common:AnnotationURL': 'https://www.oecd.org/login'},
#      {'@xmlns:common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#       'common:AnnotationTitle': 'Contact Us',
#       'common:AnnotationURL': 'http://www.oecd.org/contact/'}]}}}}

# %%
raw['message:CompactData']
# Out:
# {'ID': 'none',
#  'Test': 'false',
#  'Truncated': 'false',
#  'Prepared': '2022-10-07T08:28:55',
#  'Sender': {'@id': 'OECD',
#   'Name': [{'@xml:lang': 'en',
#     '#text': 'Organisation for Economic Co-operation and Development'},
#    {'@xml:lang': 'fr',
#     '#text': 'Organisation de coopération et de développement économiques'}]}}

# %%
def select(gender):
    return [x['OECD:Obs'] for x in data if (x['@SEX']==gender) & 
                                           (x['@COUNTRY']=='TUR') & 
                                           (x['@REF_SECTOR']=='INST_T')]

# %%
F = select('F')
F
# Out:
# [[{'@TIME': '2013', '@OBS_VALUE': '403019'},
#   {'@TIME': '2014', '@OBS_VALUE': '430079'},
#   {'@TIME': '2015', '@OBS_VALUE': '481397'},
#   {'@TIME': '2016', '@OBS_VALUE': '503284'},
#   {'@TIME': '2017', '@OBS_VALUE': '507112'},
#   {'@TIME': '2018', '@OBS_VALUE': '532882'},
#   {'@TIME': '2019', '@OBS_VALUE': '530183'},
#   {'@TIME': '2020', '@OBS_VALUE': '577408'}],
#  [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '105041'},
#   {'@TIME': '2014', '@OBS_VALUE': '141920'},
#   {'@TIME': '2015', '@OBS_VALUE': '147597'},
#   {'@TIME': '2016', '@OBS_VALUE': '163322'},
#   {'@TIME': '2017', '@OBS_VALUE': '153655'},
#   {'@TIME': '2018', '@OBS_VALUE': '168126'},
#   {'@TIME': '2019', '@OBS_VALUE': '169225'},
#   {'@TIME': '2020', '@OBS_VALUE': '256750'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '159970'},
#   {'@TIME': '2014', '@OBS_VALUE': '194732'},
#   {'@TIME': '2015', '@OBS_VALUE': '218987'},
#   {'@TIME': '2016', '@OBS_VALUE': '212838'},
#   {'@TIME': '2017', '@OBS_VALUE': '229437'},
#   {'@TIME': '2018', '@OBS_VALUE': '231150'},
#   {'@TIME': '2019', '@OBS_VALUE': '248902'},
#   {'@TIME': '2020', '@OBS_VALUE': '281665'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '17673'},
#   {'@TIME': '2014', '@OBS_VALUE': '22236'},
#   {'@TIME': '2015', '@OBS_VALUE': '24910'},
#   {'@TIME': '2016', '@OBS_VALUE': '26051'},
#   {'@TIME': '2017', '@OBS_VALUE': '28891'},
#   {'@TIME': '2018', '@OBS_VALUE': '37538'},
#   {'@TIME': '2019', '@OBS_VALUE': '52571'},
#   {'@TIME': '2020', '@OBS_VALUE': '40332'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '5109'},
#   {'@TIME': '2014', '@OBS_VALUE': '4461'},
#   {'@TIME': '2015', '@OBS_VALUE': '5432'},
#   {'@TIME': '2016', '@OBS_VALUE': '6213'},
#   {'@TIME': '2017', '@OBS_VALUE': '7160'},
#   {'@TIME': '2018', '@OBS_VALUE': '8259'},
#   {'@TIME': '2019', '@OBS_VALUE': '9269'},
#   {'@TIME': '2020', '@OBS_VALUE': '10683'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '3938'},
#   {'@TIME': '2014', '@OBS_VALUE': '2155'},
#   {'@TIME': '2015', '@OBS_VALUE': '2394'},
#   {'@TIME': '2016', '@OBS_VALUE': '2803'},
#   {'@TIME': '2017', '@OBS_VALUE': '2960'},
#   {'@TIME': '2018', '@OBS_VALUE': '3435'},
#   {'@TIME': '2019', '@OBS_VALUE': '3751'},
#   {'@TIME': '2020', '@OBS_VALUE': '3434'}]]

# %%
M = select('M')
M
# Out:
# [[{'@TIME': '2013', '@OBS_VALUE': '398529'},
#   {'@TIME': '2014', '@OBS_VALUE': '426730'},
#   {'@TIME': '2015', '@OBS_VALUE': '468771'},
#   {'@TIME': '2016', '@OBS_VALUE': '484350'},
#   {'@TIME': '2017', '@OBS_VALUE': '493876'},
#   {'@TIME': '2018', '@OBS_VALUE': '519613'},
#   {'@TIME': '2019', '@OBS_VALUE': '519277'},
#   {'@TIME': '2020', '@OBS_VALUE': '578776'}],
#  [{'@TIME': '2013', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2014', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2015', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2016', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2017', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2018', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2019', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'},
#   {'@TIME': '2020', '@OBS_VALUE': 'NaN', '@OBS_STATUS': 'm'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '127997'},
#   {'@TIME': '2014', '@OBS_VALUE': '145910'},
#   {'@TIME': '2015', '@OBS_VALUE': '146432'},
#   {'@TIME': '2016', '@OBS_VALUE': '152712'},
#   {'@TIME': '2017', '@OBS_VALUE': '141845'},
#   {'@TIME': '2018', '@OBS_VALUE': '148339'},
#   {'@TIME': '2019', '@OBS_VALUE': '141713'},
#   {'@TIME': '2020', '@OBS_VALUE': '217869'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '169205'},
#   {'@TIME': '2014', '@OBS_VALUE': '195016'},
#   {'@TIME': '2015', '@OBS_VALUE': '228307'},
#   {'@TIME': '2016', '@OBS_VALUE': '211821'},
#   {'@TIME': '2017', '@OBS_VALUE': '210328'},
#   {'@TIME': '2018', '@OBS_VALUE': '207892'},
#   {'@TIME': '2019', '@OBS_VALUE': '219738'},
#   {'@TIME': '2020', '@OBS_VALUE': '268063'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '19361'},
#   {'@TIME': '2014', '@OBS_VALUE': '28907'},
#   {'@TIME': '2015', '@OBS_VALUE': '30073'},
#   {'@TIME': '2016', '@OBS_VALUE': '30026'},
#   {'@TIME': '2017', '@OBS_VALUE': '34234'},
#   {'@TIME': '2018', '@OBS_VALUE': '45482'},
#   {'@TIME': '2019', '@OBS_VALUE': '51240'},
#   {'@TIME': '2020', '@OBS_VALUE': '40470'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '6112'},
#   {'@TIME': '2014', '@OBS_VALUE': '4840'},
#   {'@TIME': '2015', '@OBS_VALUE': '5838'},
#   {'@TIME': '2016', '@OBS_VALUE': '6574'},
#   {'@TIME': '2017', '@OBS_VALUE': '7282'},
#   {'@TIME': '2018', '@OBS_VALUE': '7694'},
#   {'@TIME': '2019', '@OBS_VALUE': '8291'},
#   {'@TIME': '2020', '@OBS_VALUE': '9291'}],
#  [{'@TIME': '2013', '@OBS_VALUE': '4796'},
#   {'@TIME': '2014', '@OBS_VALUE': '2361'},
#   {'@TIME': '2015', '@OBS_VALUE': '2798'},
#   {'@TIME': '2016', '@OBS_VALUE': '3249'},
#   {'@TIME': '2017', '@OBS_VALUE': '3085'},
#   {'@TIME': '2018', '@OBS_VALUE': '3897'},
#   {'@TIME': '2019', '@OBS_VALUE': '4318'},
#   {'@TIME': '2020', '@OBS_VALUE': '4164'}]]
